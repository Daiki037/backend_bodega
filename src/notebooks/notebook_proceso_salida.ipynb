# %%
# Parameters
fecha = "2025/05/06"

# %%
import os
import nbformat
from nbconvert.preprocessors import ExecutePreprocessor

# %%
def execute_notebook(notebook_path):
    """Ejecuta un notebook dado su path."""
    with open(notebook_path, 'r', encoding='utf-8') as f:
        notebook = nbformat.read(f, as_version=4)
    executor = ExecutePreprocessor(timeout=600, kernel_name='python3')
    try:
        executor.preprocess(notebook, {'metadata': {'path': os.path.dirname(notebook_path)}})
        print(f"Ejecutado exitosamente: {notebook_path}")
    except Exception as e:
        print(f"Error ejecutando {notebook_path}: {e}")

# %%
def execute_notebooks_in_folders(folders):
    """Ejecuta todos los notebooks en las carpetas especificadas en orden."""
    for folder in folders:
        for root, _, files in os.walk(folder):
            for file in sorted(files):  # Ordena los archivos para asegurar un orden consistente
                if file.endswith('.ipynb'):
                    notebook_path = os.path.join(root, file)
                    execute_notebook(notebook_path)

# %%
# Define las carpetas en el orden deseado
folders_to_execute = ['Landing-Bronze', 'Bronze-Silver']
execute_notebooks_in_folders(folders_to_execute)
# Out:
# Error ejecutando Landing-Bronze\Landing-bronze-Citopat.ipynb: An error occurred while executing the following cell:
# ------------------
# minio_client = conectar_minio(
#     endpoint='localhost:9000',
#     access_key='crosero',
#     secret_key='12345678',
#     secure=False  # Usar HTTPS
# )
# ------------------
#
# ----- stdout -----
# Error al conectar con MinIO: S3 operation failed; code: InvalidAccessKeyId, message: The Access Key Id you provided does not exist in our records., resource: /, request_id: 184366E72E2858B2, host_id: dd9025bab4ad464b049177c95eb6ebf374d3b3fd1af9251148b658df7ac2e3e8
# ------------------
#
# ---------------------------------------------------------------------------
# S3Error                                   Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 minio_client = conectar_minio(
#       2     endpoint='localhost:9000',
#       3     access_key='crosero',
#       4     secret_key='12345678',
#       5     secure=False  # Usar HTTPS
#       6 )
#
# File <string>:45, in conectar_minio(endpoint, access_key, secret_key, secure)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\minio\api.py:678, in Minio.list_buckets(self)
#     666 def list_buckets(self) -> list[Bucket]:
#     667     """
#     668     List information of all accessible buckets.
#     669
#    (...)    675             print(bucket.name, bucket.creation_date)
#     676     """
# --> 678     response = self._execute("GET")
#     679     result = unmarshal(ListAllMyBucketsResult, response.data.decode())
#     680     return result.buckets
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\minio\api.py:441, in Minio._execute(self, method, bucket_name, object_name, body, headers, query_params, preload_content, no_body_trace)
#     438 region = self._get_region(bucket_name)
#     440 try:
# --> 441     return self._url_open(
#     442         method,
#     443         region,
#     444         bucket_name=bucket_name,
#     445         object_name=object_name,
#     446         body=body,
#     447         headers=headers,
#     448         query_params=query_params,
#     449         preload_content=preload_content,
#     450         no_body_trace=no_body_trace,
#     451     )
#     452 except S3Error as exc:
#     453     if exc.code != "RetryHead":
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\minio\api.py:424, in Minio._url_open(self, method, region, bucket_name, object_name, body, headers, query_params, preload_content, no_body_trace)
#     421     if bucket_name is not None:
#     422         self._region_map.pop(bucket_name, None)
# --> 424 raise response_error
#
# S3Error: S3 operation failed; code: InvalidAccessKeyId, message: The Access Key Id you provided does not exist in our records., resource: /, request_id: 184366E72E2858B2, host_id: dd9025bab4ad464b049177c95eb6ebf374d3b3fd1af9251148b658df7ac2e3e8
# Error ejecutando Landing-Bronze\Landing-bronze-laboratorio Fernando Sanzon.ipynb: An error occurred while executing the following cell:
# ------------------
# minio_client = conectar_minio(
#     endpoint='localhost:9000',
#     access_key='crosero',
#     secret_key='12345678',
#     secure=False  # Usar HTTPS
# )
# ------------------
#
# ----- stdout -----
# Error al conectar con MinIO: S3 operation failed; code: InvalidAccessKeyId, message: The Access Key Id you provided does not exist in our records., resource: /, request_id: 184366E7F4861D94, host_id: dd9025bab4ad464b049177c95eb6ebf374d3b3fd1af9251148b658df7ac2e3e8
# ------------------
#
# ---------------------------------------------------------------------------
# S3Error                                   Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 minio_client = conectar_minio(
#       2     endpoint='localhost:9000',
#       3     access_key='crosero',
#       4     secret_key='12345678',
#       5     secure=False  # Usar HTTPS
#       6 )
#
# File <string>:45, in conectar_minio(endpoint, access_key, secret_key, secure)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\minio\api.py:678, in Minio.list_buckets(self)
#     666 def list_buckets(self) -> list[Bucket]:
#     667     """
#     668     List information of all accessible buckets.
#     669
#    (...)    675             print(bucket.name, bucket.creation_date)
#     676     """
# --> 678     response = self._execute("GET")
#     679     result = unmarshal(ListAllMyBucketsResult, response.data.decode())
#     680     return result.buckets
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\minio\api.py:441, in Minio._execute(self, method, bucket_name, object_name, body, headers, query_params, preload_content, no_body_trace)
#     438 region = self._get_region(bucket_name)
#     440 try:
# --> 441     return self._url_open(
#     442         method,
#     443         region,
#     444         bucket_name=bucket_name,
#     445         object_name=object_name,
#     446         body=body,
#     447         headers=headers,
#     448         query_params=query_params,
#     449         preload_content=preload_content,
#     450         no_body_trace=no_body_trace,
#     451     )
#     452 except S3Error as exc:
#     453     if exc.code != "RetryHead":
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\minio\api.py:424, in Minio._url_open(self, method, region, bucket_name, object_name, body, headers, query_params, preload_content, no_body_trace)
#     421     if bucket_name is not None:
#     422         self._region_map.pop(bucket_name, None)
# --> 424 raise response_error
#
# S3Error: S3 operation failed; code: InvalidAccessKeyId, message: The Access Key Id you provided does not exist in our records., resource: /, request_id: 184366E7F4861D94, host_id: dd9025bab4ad464b049177c95eb6ebf374d3b3fd1af9251148b658df7ac2e3e8
# Error ejecutando Landing-Bronze\Landing-bronze-laboratorio Jimenez Ipiales.ipynb: An error occurred while executing the following cell:
# ------------------
# minio_client = conectar_minio(
#     endpoint='localhost:9000',
#     access_key='crosero',
#     secret_key='12345678',
#     secure=False  # Usar HTTPS
# )
# ------------------
#
# ----- stdout -----
# Error al conectar con MinIO: S3 operation failed; code: InvalidAccessKeyId, message: The Access Key Id you provided does not exist in our records., resource: /, request_id: 184366E89D1978FB, host_id: dd9025bab4ad464b049177c95eb6ebf374d3b3fd1af9251148b658df7ac2e3e8
# ------------------
#
# ---------------------------------------------------------------------------
# S3Error                                   Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 minio_client = conectar_minio(
#       2     endpoint='localhost:9000',
#       3     access_key='crosero',
#       4     secret_key='12345678',
#       5     secure=False  # Usar HTTPS
#       6 )
#
# File <string>:45, in conectar_minio(endpoint, access_key, secret_key, secure)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\minio\api.py:678, in Minio.list_buckets(self)
#     666 def list_buckets(self) -> list[Bucket]:
#     667     """
#     668     List information of all accessible buckets.
#     669
#    (...)    675             print(bucket.name, bucket.creation_date)
#     676     """
# --> 678     response = self._execute("GET")
#     679     result = unmarshal(ListAllMyBucketsResult, response.data.decode())
#     680     return result.buckets
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\minio\api.py:441, in Minio._execute(self, method, bucket_name, object_name, body, headers, query_params, preload_content, no_body_trace)
#     438 region = self._get_region(bucket_name)
#     440 try:
# --> 441     return self._url_open(
#     442         method,
#     443         region,
#     444         bucket_name=bucket_name,
#     445         object_name=object_name,
#     446         body=body,
#     447         headers=headers,
#     448         query_params=query_params,
#     449         preload_content=preload_content,
#     450         no_body_trace=no_body_trace,
#     451     )
#     452 except S3Error as exc:
#     453     if exc.code != "RetryHead":
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\minio\api.py:424, in Minio._url_open(self, method, region, bucket_name, object_name, body, headers, query_params, preload_content, no_body_trace)
#     421     if bucket_name is not None:
#     422         self._region_map.pop(bucket_name, None)
# --> 424 raise response_error
#
# S3Error: S3 operation failed; code: InvalidAccessKeyId, message: The Access Key Id you provided does not exist in our records., resource: /, request_id: 184366E89D1978FB, host_id: dd9025bab4ad464b049177c95eb6ebf374d3b3fd1af9251148b658df7ac2e3e8
# Error ejecutando Landing-Bronze\Landing-bronze-laboratorio Jimenez Pasto.ipynb: An error occurred while executing the following cell:
# ------------------
# minio_client = conectar_minio(
#     endpoint='localhost:9000',
#     access_key='crosero',
#     secret_key='12345678',
#     secure=False  # Usar HTTPS
# )
# ------------------
#
# ----- stdout -----
# Error al conectar con MinIO: S3 operation failed; code: InvalidAccessKeyId, message: The Access Key Id you provided does not exist in our records., resource: /, request_id: 184366E947A6492C, host_id: dd9025bab4ad464b049177c95eb6ebf374d3b3fd1af9251148b658df7ac2e3e8
# ------------------
#
# ---------------------------------------------------------------------------
# S3Error                                   Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 minio_client = conectar_minio(
#       2     endpoint='localhost:9000',
#       3     access_key='crosero',
#       4     secret_key='12345678',
#       5     secure=False  # Usar HTTPS
#       6 )
#
# File <string>:45, in conectar_minio(endpoint, access_key, secret_key, secure)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\minio\api.py:678, in Minio.list_buckets(self)
#     666 def list_buckets(self) -> list[Bucket]:
#     667     """
#     668     List information of all accessible buckets.
#     669
#    (...)    675             print(bucket.name, bucket.creation_date)
#     676     """
# --> 678     response = self._execute("GET")
#     679     result = unmarshal(ListAllMyBucketsResult, response.data.decode())
#     680     return result.buckets
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\minio\api.py:441, in Minio._execute(self, method, bucket_name, object_name, body, headers, query_params, preload_content, no_body_trace)
#     438 region = self._get_region(bucket_name)
#     440 try:
# --> 441     return self._url_open(
#     442         method,
#     443         region,
#     444         bucket_name=bucket_name,
#     445         object_name=object_name,
#     446         body=body,
#     447         headers=headers,
#     448         query_params=query_params,
#     449         preload_content=preload_content,
#     450         no_body_trace=no_body_trace,
#     451     )
#     452 except S3Error as exc:
#     453     if exc.code != "RetryHead":
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\minio\api.py:424, in Minio._url_open(self, method, region, bucket_name, object_name, body, headers, query_params, preload_content, no_body_trace)
#     421     if bucket_name is not None:
#     422         self._region_map.pop(bucket_name, None)
# --> 424 raise response_error
#
# S3Error: S3 operation failed; code: InvalidAccessKeyId, message: The Access Key Id you provided does not exist in our records., resource: /, request_id: 184366E947A6492C, host_id: dd9025bab4ad464b049177c95eb6ebf374d3b3fd1af9251148b658df7ac2e3e8
# Error ejecutando Landing-Bronze\Landing-bronze-laboratorio Monica Arcos.ipynb: An error occurred while executing the following cell:
# ------------------
# minio_client = conectar_minio(
#     endpoint='localhost:9000',
#     access_key='crosero',
#     secret_key='12345678',
#     secure=False  # Usar HTTPS
# )
# ------------------
#
# ----- stdout -----
# Error al conectar con MinIO: S3 operation failed; code: InvalidAccessKeyId, message: The Access Key Id you provided does not exist in our records., resource: /, request_id: 184366E9EC6958D9, host_id: dd9025bab4ad464b049177c95eb6ebf374d3b3fd1af9251148b658df7ac2e3e8
# ------------------
#
# ---------------------------------------------------------------------------
# S3Error                                   Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 minio_client = conectar_minio(
#       2     endpoint='localhost:9000',
#       3     access_key='crosero',
#       4     secret_key='12345678',
#       5     secure=False  # Usar HTTPS
#       6 )
#
# File <string>:45, in conectar_minio(endpoint, access_key, secret_key, secure)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\minio\api.py:678, in Minio.list_buckets(self)
#     666 def list_buckets(self) -> list[Bucket]:
#     667     """
#     668     List information of all accessible buckets.
#     669
#    (...)    675             print(bucket.name, bucket.creation_date)
#     676     """
# --> 678     response = self._execute("GET")
#     679     result = unmarshal(ListAllMyBucketsResult, response.data.decode())
#     680     return result.buckets
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\minio\api.py:441, in Minio._execute(self, method, bucket_name, object_name, body, headers, query_params, preload_content, no_body_trace)
#     438 region = self._get_region(bucket_name)
#     440 try:
# --> 441     return self._url_open(
#     442         method,
#     443         region,
#     444         bucket_name=bucket_name,
#     445         object_name=object_name,
#     446         body=body,
#     447         headers=headers,
#     448         query_params=query_params,
#     449         preload_content=preload_content,
#     450         no_body_trace=no_body_trace,
#     451     )
#     452 except S3Error as exc:
#     453     if exc.code != "RetryHead":
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\minio\api.py:424, in Minio._url_open(self, method, region, bucket_name, object_name, body, headers, query_params, preload_content, no_body_trace)
#     421     if bucket_name is not None:
#     422         self._region_map.pop(bucket_name, None)
# --> 424 raise response_error
#
# S3Error: S3 operation failed; code: InvalidAccessKeyId, message: The Access Key Id you provided does not exist in our records., resource: /, request_id: 184366E9EC6958D9, host_id: dd9025bab4ad464b049177c95eb6ebf374d3b3fd1af9251148b658df7ac2e3e8
# Ejecutado exitosamente: Landing-Bronze\Landing-bronze-laboratorio San Pedro.ipynb
# Ejecutado exitosamente: Landing-Bronze\Utils.ipynb
# Error ejecutando Bronze-Silver\Bronze-silver-Citopat.ipynb: An error occurred while executing the following cell:
# ------------------
# minio_client = conectar_minio(
#     endpoint='localhost:9000',
#     access_key='crosero',
#     secret_key='12345678',
#     secure=False  # Usar HTTPS
# )
# ------------------
#
# ----- stdout -----
# Error al conectar con MinIO: S3 operation failed; code: InvalidAccessKeyId, message: The Access Key Id you provided does not exist in our records., resource: /, request_id: 184366EC41F469D0, host_id: dd9025bab4ad464b049177c95eb6ebf374d3b3fd1af9251148b658df7ac2e3e8
# ------------------
#
# ---------------------------------------------------------------------------
# S3Error                                   Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 minio_client = conectar_minio(
#       2     endpoint='localhost:9000',
#       3     access_key='crosero',
#       4     secret_key='12345678',
#       5     secure=False  # Usar HTTPS
#       6 )
#
# File <string>:45, in conectar_minio(endpoint, access_key, secret_key, secure)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\minio\api.py:678, in Minio.list_buckets(self)
#     666 def list_buckets(self) -> list[Bucket]:
#     667     """
#     668     List information of all accessible buckets.
#     669
#    (...)    675             print(bucket.name, bucket.creation_date)
#     676     """
# --> 678     response = self._execute("GET")
#     679     result = unmarshal(ListAllMyBucketsResult, response.data.decode())
#     680     return result.buckets
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\minio\api.py:441, in Minio._execute(self, method, bucket_name, object_name, body, headers, query_params, preload_content, no_body_trace)
#     438 region = self._get_region(bucket_name)
#     440 try:
# --> 441     return self._url_open(
#     442         method,
#     443         region,
#     444         bucket_name=bucket_name,
#     445         object_name=object_name,
#     446         body=body,
#     447         headers=headers,
#     448         query_params=query_params,
#     449         preload_content=preload_content,
#     450         no_body_trace=no_body_trace,
#     451     )
#     452 except S3Error as exc:
#     453     if exc.code != "RetryHead":
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\minio\api.py:424, in Minio._url_open(self, method, region, bucket_name, object_name, body, headers, query_params, preload_content, no_body_trace)
#     421     if bucket_name is not None:
#     422         self._region_map.pop(bucket_name, None)
# --> 424 raise response_error
#
# S3Error: S3 operation failed; code: InvalidAccessKeyId, message: The Access Key Id you provided does not exist in our records., resource: /, request_id: 184366EC41F469D0, host_id: dd9025bab4ad464b049177c95eb6ebf374d3b3fd1af9251148b658df7ac2e3e8
# Error ejecutando Bronze-Silver\Bronze-silver-Laboratorio Fernado Sanzon.ipynb: An error occurred while executing the following cell:
# ------------------
# minio_client = conectar_minio(
#     endpoint='localhost:9000',
#     access_key='crosero',
#     secret_key='12345678',
#     secure=False  # Usar HTTPS
# )
# ------------------
#
# ----- stdout -----
# Error al conectar con MinIO: S3 operation failed; code: InvalidAccessKeyId, message: The Access Key Id you provided does not exist in our records., resource: /, request_id: 184366ECF371ADD1, host_id: dd9025bab4ad464b049177c95eb6ebf374d3b3fd1af9251148b658df7ac2e3e8
# ------------------
#
# ---------------------------------------------------------------------------
# S3Error                                   Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 minio_client = conectar_minio(
#       2     endpoint='localhost:9000',
#       3     access_key='crosero',
#       4     secret_key='12345678',
#       5     secure=False  # Usar HTTPS
#       6 )
#
# File <string>:45, in conectar_minio(endpoint, access_key, secret_key, secure)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\minio\api.py:678, in Minio.list_buckets(self)
#     666 def list_buckets(self) -> list[Bucket]:
#     667     """
#     668     List information of all accessible buckets.
#     669
#    (...)    675             print(bucket.name, bucket.creation_date)
#     676     """
# --> 678     response = self._execute("GET")
#     679     result = unmarshal(ListAllMyBucketsResult, response.data.decode())
#     680     return result.buckets
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\minio\api.py:441, in Minio._execute(self, method, bucket_name, object_name, body, headers, query_params, preload_content, no_body_trace)
#     438 region = self._get_region(bucket_name)
#     440 try:
# --> 441     return self._url_open(
#     442         method,
#     443         region,
#     444         bucket_name=bucket_name,
#     445         object_name=object_name,
#     446         body=body,
#     447         headers=headers,
#     448         query_params=query_params,
#     449         preload_content=preload_content,
#     450         no_body_trace=no_body_trace,
#     451     )
#     452 except S3Error as exc:
#     453     if exc.code != "RetryHead":
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\minio\api.py:424, in Minio._url_open(self, method, region, bucket_name, object_name, body, headers, query_params, preload_content, no_body_trace)
#     421     if bucket_name is not None:
#     422         self._region_map.pop(bucket_name, None)
# --> 424 raise response_error
#
# S3Error: S3 operation failed; code: InvalidAccessKeyId, message: The Access Key Id you provided does not exist in our records., resource: /, request_id: 184366ECF371ADD1, host_id: dd9025bab4ad464b049177c95eb6ebf374d3b3fd1af9251148b658df7ac2e3e8
# Error ejecutando Bronze-Silver\Bronze-silver-laboratorio Jimenez.ipynb: An error occurred while executing the following cell:
# ------------------
# minio_client = conectar_minio(
#     endpoint='localhost:9000',
#     access_key='crosero',
#     secret_key='12345678',
#     secure=False  # Usar HTTPS
# )
# ------------------
#
# ----- stdout -----
# Error al conectar con MinIO: S3 operation failed; code: InvalidAccessKeyId, message: The Access Key Id you provided does not exist in our records., resource: /, request_id: 184366EDA4A24056, host_id: dd9025bab4ad464b049177c95eb6ebf374d3b3fd1af9251148b658df7ac2e3e8
# ------------------
#
# ---------------------------------------------------------------------------
# S3Error                                   Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 minio_client = conectar_minio(
#       2     endpoint='localhost:9000',
#       3     access_key='crosero',
#       4     secret_key='12345678',
#       5     secure=False  # Usar HTTPS
#       6 )
#
# File <string>:45, in conectar_minio(endpoint, access_key, secret_key, secure)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\minio\api.py:678, in Minio.list_buckets(self)
#     666 def list_buckets(self) -> list[Bucket]:
#     667     """
#     668     List information of all accessible buckets.
#     669
#    (...)    675             print(bucket.name, bucket.creation_date)
#     676     """
# --> 678     response = self._execute("GET")
#     679     result = unmarshal(ListAllMyBucketsResult, response.data.decode())
#     680     return result.buckets
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\minio\api.py:441, in Minio._execute(self, method, bucket_name, object_name, body, headers, query_params, preload_content, no_body_trace)
#     438 region = self._get_region(bucket_name)
#     440 try:
# --> 441     return self._url_open(
#     442         method,
#     443         region,
#     444         bucket_name=bucket_name,
#     445         object_name=object_name,
#     446         body=body,
#     447         headers=headers,
#     448         query_params=query_params,
#     449         preload_content=preload_content,
#     450         no_body_trace=no_body_trace,
#     451     )
#     452 except S3Error as exc:
#     453     if exc.code != "RetryHead":
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\minio\api.py:424, in Minio._url_open(self, method, region, bucket_name, object_name, body, headers, query_params, preload_content, no_body_trace)
#     421     if bucket_name is not None:
#     422         self._region_map.pop(bucket_name, None)
# --> 424 raise response_error
#
# S3Error: S3 operation failed; code: InvalidAccessKeyId, message: The Access Key Id you provided does not exist in our records., resource: /, request_id: 184366EDA4A24056, host_id: dd9025bab4ad464b049177c95eb6ebf374d3b3fd1af9251148b658df7ac2e3e8
# Error ejecutando Bronze-Silver\Bronze-silver-laboratorio Monica Arcos.ipynb: An error occurred while executing the following cell:
# ------------------
# minio_client = conectar_minio(
#     endpoint='localhost:9000',
#     access_key='crosero',
#     secret_key='12345678',
#     secure=False  # Usar HTTPS
# )
# ------------------
#
# ----- stdout -----
# Error al conectar con MinIO: S3 operation failed; code: InvalidAccessKeyId, message: The Access Key Id you provided does not exist in our records., resource: /, request_id: 184366EE5A6D428F, host_id: dd9025bab4ad464b049177c95eb6ebf374d3b3fd1af9251148b658df7ac2e3e8
# ------------------
#
# ---------------------------------------------------------------------------
# S3Error                                   Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 minio_client = conectar_minio(
#       2     endpoint='localhost:9000',
#       3     access_key='crosero',
#       4     secret_key='12345678',
#       5     secure=False  # Usar HTTPS
#       6 )
#
# File <string>:45, in conectar_minio(endpoint, access_key, secret_key, secure)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\minio\api.py:678, in Minio.list_buckets(self)
#     666 def list_buckets(self) -> list[Bucket]:
#     667     """
#     668     List information of all accessible buckets.
#     669
#    (...)    675             print(bucket.name, bucket.creation_date)
#     676     """
# --> 678     response = self._execute("GET")
#     679     result = unmarshal(ListAllMyBucketsResult, response.data.decode())
#     680     return result.buckets
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\minio\api.py:441, in Minio._execute(self, method, bucket_name, object_name, body, headers, query_params, preload_content, no_body_trace)
#     438 region = self._get_region(bucket_name)
#     440 try:
# --> 441     return self._url_open(
#     442         method,
#     443         region,
#     444         bucket_name=bucket_name,
#     445         object_name=object_name,
#     446         body=body,
#     447         headers=headers,
#     448         query_params=query_params,
#     449         preload_content=preload_content,
#     450         no_body_trace=no_body_trace,
#     451     )
#     452 except S3Error as exc:
#     453     if exc.code != "RetryHead":
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\minio\api.py:424, in Minio._url_open(self, method, region, bucket_name, object_name, body, headers, query_params, preload_content, no_body_trace)
#     421     if bucket_name is not None:
#     422         self._region_map.pop(bucket_name, None)
# --> 424 raise response_error
#
# S3Error: S3 operation failed; code: InvalidAccessKeyId, message: The Access Key Id you provided does not exist in our records., resource: /, request_id: 184366EE5A6D428F, host_id: dd9025bab4ad464b049177c95eb6ebf374d3b3fd1af9251148b658df7ac2e3e8
# Ejecutado exitosamente: Bronze-Silver\Bronze-silver-laboratorio San Pedro.ipynb
# Ejecutado exitosamente: Bronze-Silver\Utils.ipynb
